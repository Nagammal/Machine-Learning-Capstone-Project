# %%
import pandas as pd
dataset = pd.read_csv("../Datasets/Clustering/Bank Customer Segmentation/bank_transactions.csv")
dataset
# Out:
#        TransactionID CustomerID CustomerDOB CustGender CustLocation  \
# 0                 T1   C5841053     10/1/94          F   JAMSHEDPUR
# 1                 T2   C2142763      4/4/57          M      JHAJJAR
# 2                 T3   C4417068    26/11/96          F       MUMBAI
# 3                 T4   C5342380     14/9/73          F       MUMBAI
# 4                 T5   C9031234     24/3/88          F  NAVI MUMBAI
# ...              ...        ...         ...        ...          ...
# 748957       T748958   C4210149     14/3/75          M       MUMBAI
# 748958       T748959   C3033441    1/1/1800          M        DELHI
# 748959       T748960   C4336292     17/8/91          M     JAMNAGAR
# 748960       T748961   C7813230    1/1/1800          M    NEW DELHI
# 748961       T748962   C1718414     7/10/76          M    NEW DELHI
#
#         CustAccountBalance TransactionDate  TransactionTime  \
# 0                 17819.05          2/8/16         143207.0
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 748962 entries, 0 to 748961
# Data columns (total 9 columns):
# TransactionID              748962 non-null object
# CustomerID                 748962 non-null object
# CustomerDOB                746511 non-null object
# CustGender                 748148 non-null object
# CustLocation               748846 non-null object
# CustAccountBalance         747077 non-null float64
# TransactionDate            748962 non-null object
# TransactionTime            748961 non-null float64
# TransactionAmount (INR)    748961 non-null float64
# dtypes: float64(3), object(6)
# memory usage: 51.4+ MB

# %%
dataset.describe()
# Out:
#        CustAccountBalance  TransactionTime  TransactionAmount (INR)
# count        7.470770e+05    748961.000000             7.489610e+05
# mean         1.155373e+05    157547.820947             1.583032e+03
# std          7.668946e+05     51401.611495             6.645791e+03
# min          0.000000e+00         0.000000             0.000000e+00
# 25%          4.681180e+03    124350.000000             1.600000e+02
# 50%          1.703382e+04    164642.000000             4.600000e+02
# 75%          5.872810e+04    200334.000000             1.200000e+03
# max          1.150355e+08    235959.000000             1.560035e+06

# %%
dataset.isna().sum()
# Out:
# TransactionID                 0
# CustomerID                    0
# CustomerDOB                2451
# CustGender                  814
# CustLocation                116
# CustAccountBalance         1885
# TransactionDate               0
# TransactionTime               1
# TransactionAmount (INR)       1
# dtype: int64

# %%
dataset.to_csv('../Datasets/Clustering/Bank Customer Segmentation/raw_dataset.csv', index=False)
